# %% [markdown]
# ## Day 2 notes
# - Tripped up on `{"even" if n % 2 == 0 else "odd"}` — the extra `{ }` turned
#   the value into a one-item set instead of a plain string. Lesson: `{ }` in
#   an expression always builds a set/dict, never just "groups" something.
# - Clicked: `{ }` is a set unless there's a `:` inside, then it's a dict.
# - Learned `.append()` returns `None`, so `x = x.append(4)` silently breaks `x`.

# %%
my_list = [1, 2, 4, 2]        # ordered, mutable, allows duplicates
my_tuple = (1, 4, 3)          # ordered, immutable
my_dict = {"a": 1, "b": 2, "c": 3}    # key-value pairs, mutable
my_set = {1, 2, 3, 2, 4, 2}         # unordered, mutable, no duplicates

print(my_list, my_tuple, my_dict, my_set)
# Out:
# [1, 2, 4, 2] (1, 4, 3) {'a': 1, 'b': 2, 'c': 3} {1, 2, 3, 4}

# %%
# the "long way"
squares = []
for n in range(10):
    squares.append(n ** 3)
print(squares)

# the comprehension way — same result, one line
squares = [n ** 2 for n in range(10)]
print(squares)
# Out:
# [0, 1, 8, 27, 64, 125, 216, 343, 512, 729]
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
even_squares = [n ** 2 for n in range(10) if n % 2 == 1]
print(even_squares)
# Out:
# [1, 9, 25, 49, 81]

# %%
words = ["python", "ai", "engineer"]

word_lengths = {w: len(w) for w in words}        # dict comprehension
print(word_lengths)

unique_lengths = {len(w) for w in words}          # set comprehension
print(unique_lengths)
# Out:
# {'python': 6, 'ai': 2, 'engineer': 8}
# {8, 2, 6}

# %%
evenodd = {n: "even" if n % 2 == 0 else "odd" for n in range(20)}  
print(evenodd)  # dict comprehension with condition
# Out:
# {0: 'even', 1: 'odd', 2: 'even', 3: 'odd', 4: 'even', 5: 'odd', 6: 'even', 7: 'odd', 8: 'even', 9: 'odd', 10: 'even', 11: 'odd', 12: 'even', 13: 'odd', 14: 'even', 15: 'odd', 16: 'even', 17: 'odd', 18: 'even', 19: 'odd'}
